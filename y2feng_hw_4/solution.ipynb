# %% [markdown]
# Assignment 3
# Yiduo Feng
# Class: CS 677
# Date: 04/11/2022

# %% [markdown]
# Question 1:
# 1. load the data into Pandas dataframe. Extract two dataframes
# with the above 4 features: df 0 for surviving patients (DEATH EVENT
# = 0) and df 1 for deceased patients (DEATH EVENT = 1)

# %% [markdown]
# 2. for each dataset, construct the visual representations of
# correponding correlation matrices M0 (from df 0) and M1
# (from df 1) and save the plots into two separate files

# %%
from Question1 import *
show_df()
get_M0()
get_M1()
# Out:
#                           creatinine_phosphokinase  serum_creatinine  \
# creatinine_phosphokinase                  1.000000         -0.043110
# serum_creatinine                         -0.043110          1.000000
# serum_sodium                             -0.002474         -0.215651
# platelets                                -0.012940         -0.031217
# DEATH_EVENT                                    NaN               NaN
#
#                           serum_sodium  platelets  DEATH_EVENT
# creatinine_phosphokinase     -0.002474  -0.012940          NaN
# serum_creatinine             -0.215651  -0.031217          NaN
# serum_sodium                  1.000000   0.001807          NaN
# platelets                     0.001807   1.000000          NaN
# DEATH_EVENT                        NaN        NaN          NaN
#                           creatinine_phosphokinase  serum_creatinine  \
# creatinine_phosphokinase                  1.000000         -0.033407
# serum_creatinine                         -0.033407          1.000000
# serum_sodium                              0.148823         -0.094011
# platelets                                 0.078808         -0.029384
# DEATH_EVENT                                    NaN               NaN
#
#                           serum_sodium  platelets  DEATH_EVENT
# creatinine_phosphokinase      0.148823   0.078808          NaN
# serum_creatinine             -0.094011  -0.029384          NaN
# serum_sodium                  1.000000   0.141284          NaN
# platelets                     0.141284   1.000000          NaN
# DEATH_EVENT                        NaN        NaN          NaN
# df_0
#      creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets  \
# 14                         80               1.0           138   427000.0
# 20                         52               1.3           137   276000.0
# 23                         63               0.8           135   368000.0
# 33                        159               1.2           138   302000.0
# 38                       2656               2.3           137   305000.0
# ..                        ...               ...           ...        ...
# 294                        61               1.1           143   155000.0
# 295                      1820               1.2           139   270000.0
# 296                      2060               0.8           138   742000.0
# 297                      2413               1.4           140   140000.0
# 298                       196               1.6           136   395000.0
#
#      DEATH_EVENT
# 14             0
# 20             0
# 23             0
# 33             0
# 38             0
# ..           ...
# 294            0
# 295            0
# 296            0
# 297            0
# 298            0
#
# [203 rows x 5 columns]
# df_1
#      creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets  \
# 0                         582              1.90           130  265000.00
# 1                        7861              1.10           136  263358.03
# 2                         146              1.30           129  162000.00
# 3                         111              1.90           137  210000.00
# 4                         160              2.70           116  327000.00
# ..                        ...               ...           ...        ...
# 220                       582              1.83           134  263358.03
# 230                       166              1.70           127   62000.00
# 246                      2017              1.10           138  314000.00
# 262                       258              1.40           129  198000.00
# 266                      1199              1.83           134  263358.03
#
#      DEATH_EVENT
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 220            1
# 230            1
# 246            1
# 262            1
# 266            1
#
# [96 rows x 5 columns]
#                           creatinine_phosphokinase  serum_creatinine  \
# creatinine_phosphokinase                  1.000000         -0.043110
# serum_creatinine                         -0.043110          1.000000
# serum_sodium                             -0.002474         -0.215651
# platelets                                -0.012940         -0.031217
# DEATH_EVENT                                    NaN               NaN
#
#                           serum_sodium  platelets  DEATH_EVENT
# creatinine_phosphokinase     -0.002474  -0.012940          NaN
# serum_creatinine             -0.215651  -0.031217          NaN
# serum_sodium                  1.000000   0.001807          NaN
# platelets                     0.001807   1.000000          NaN
# DEATH_EVENT                        NaN        NaN          NaN
#                           creatinine_phosphokinase  serum_creatinine  \
# creatinine_phosphokinase                  1.000000         -0.033407
# serum_creatinine                         -0.033407          1.000000
# serum_sodium                              0.148823         -0.094011
# platelets                                 0.078808         -0.029384
# DEATH_EVENT                                    NaN               NaN
#
#                           serum_sodium  platelets  DEATH_EVENT
# creatinine_phosphokinase      0.148823   0.078808          NaN
# serum_creatinine             -0.094011  -0.029384          NaN
# serum_sodium                  1.000000   0.141284          NaN
# platelets                     0.141284   1.000000          NaN
# DEATH_EVENT                        NaN        NaN          NaN

# %%
get_M0()
get_M1()

# %% [markdown]
# 3. examine your correlation matrix plots visually and answer
# the following:

# %% [markdown]
# (a) which features have the highest correlation for surviving
# patients?

# %% [markdown]
# platelets

# %% [markdown]
# (b) which features have the lowest correlation for surviving
# patients?

# %% [markdown]
# serum_sodium and serum_creatinine

# %% [markdown]
# (c) which features have the highest correlation for deceased
# patients?

# %% [markdown]
# creatining_phosphokinase and serum_sodium

# %% [markdown]
# (d) which features have the lowest correlation for deceased
# patients?

# %% [markdown]
# serum_sodium and serum_creatinine

# %% [markdown]
# (e) are results the same for both cases?

# %% [markdown]
# The lowest correlation are the same but the numbers are different.
# The highest are different, but platelets is the second highest one for
# deceased.

# %% [markdown]
# Question 2: In this question you will compare a number of
# different models using linear systems (including linear regression). You choose one feature X as independent variable X
# and another feature Y as dependent.
# Group 3: X: serum sodium, Y : serum creatinine

# %% [markdown]
# 1. y = ax + b (simple linear regression)

# %% [markdown]
# 2. y = ax2 + bx + c (quadratic)

# %% [markdown]
# 3. y = ax3 + bx2 + cx + d (cubic spline)

# %% [markdown]
# 4. y = a log x + b (GLM - generalized linear model)

# %% [markdown]
# 5. log y = a log x + b (GLM - generalized linear model)

# %%
from Question2 import *
get_graph_0()
get_graph_1()
# Out:
# -----------------surviving------------------------
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [51.32026458]
# rmes =  0.2531497075046555
# weight =  [ 7.16150913e-05 -7.35411351e-02  9.92027846e+00]
#            2
# 7.162e-05 x - 0.07354 x + 9.92
# SSE =  [51.23799242]
# rmes =  0.2523387031369553
# weight =  [ 4.98280309e-04 -1.95516571e-01  2.54146755e+01 -1.09231694e+03]
#            3          2
# 0.0004983 x - 0.1955 x + 25.41 x - 1092
# SSE =  [64.70959393]
# rmes =  0.4024732359512419
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [5290.01859808]
# rmes =  2689.763241828733
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [1.91649192e+09]
# rmes =  353031648324099.8
# -----------------deceased------------------------
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [131.88928375]
# rmes =  7.549819083475413
# weight =  [-2.46214939e-03  6.13985369e-01 -3.62625582e+01]
#            2
# -0.002462 x + 0.614 x - 36.26
# SSE =  [134.52363664]
# rmes =  7.85443090954328
# weight =  [ 1.31040708e-04 -5.49882805e-02  7.62112048e+00 -3.47354908e+02]
#           3           2
# 0.000131 x - 0.05499 x + 7.621 x - 347.4
# SSE =  [132.21838367]
# rmes =  7.587543828543042
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [1921.83744917]
# rmes =  1603.0638806560726
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [5.09238018e+08]
# rmes =  112553541334338.8
# -----------------surviving------------------------
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [51.32026458]
# rmes =  0.2531497075046555
# weight =  [ 7.16150913e-05 -7.35411351e-02  9.92027846e+00]
#            2
# 7.162e-05 x - 0.07354 x + 9.92
# SSE =  [51.23799242]
# rmes =  0.2523387031369553
# weight =  [ 4.98280309e-04 -1.95516571e-01  2.54146755e+01 -1.09231694e+03]
#            3          2
# 0.0004983 x - 0.1955 x + 25.41 x - 1092
# SSE =  [64.70959393]
# rmes =  0.4024732359512419
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [5290.01859808]
# rmes =  2689.763241828733
# weight =  [-0.05439031  8.64225298]
#
# -0.05439 x + 8.642
# SSE =  [1.91649192e+09]
# rmes =  353031648324099.8
# -----------------deceased------------------------
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [131.88928375]
# rmes =  7.549819083475413
# weight =  [-2.46214939e-03  6.13985369e-01 -3.62625582e+01]
#            2
# -0.002462 x + 0.614 x - 36.26
# SSE =  [134.52363664]
# rmes =  7.85443090954328
# weight =  [ 1.31040708e-04 -5.49882805e-02  7.62112048e+00 -3.47354908e+02]
#           3           2
# 0.000131 x - 0.05499 x + 7.621 x - 347.4
# SSE =  [132.21838367]
# rmes =  7.587543828543042
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [1921.83744917]
# rmes =  1603.0638806560726
# weight =  [-0.04909822  8.33024963]
#
# -0.0491 x + 8.33
# SSE =  [5.09238018e+08]
# rmes =  112553541334338.8

# %% [markdown]
# Question 3: Summarize your results from question 2 in a
# table like shown below:

# %%
from Question3 import *
get_table()
# Out:
# +------------------------+---------------------+---------------------+
# |         Model          | SSE (death event=0) | SSE (death event=1) |
# +------------------------+---------------------+---------------------+
# |       y = ax + b       |  51.32026458309072  |  131.88928375090737 |
# |    y = ax2 + bx + c    |  51.23799242199956  |  134.5236366427391  |
# | y = ax3 + bx2 + cx + d |  64.70959393194123  |  132.21838367248017 |
# |    y = a log x + b     |  5290.018598075638  |  1921.8374491698287 |
# |  log y = a log x + b   |  1916491917.3228822 |  509238018.2530725  |
# +------------------------+---------------------+---------------------+

# %% [markdown]
# 1. which model was the best (smallest SSE) for surviving patients? for deceased patients?

# %% [markdown]
# y = ax+b is best for both surviving patients and deceased patients.

# %% [markdown]
# 2. which model was the worst (largest SSE) for surving patients? for deceased patients?

# %% [markdown]
# log y = a log x + b is worst for both surviving patients and deceased patients.
